# %%
#5 iterations로 나누되 이번에는
#validation 없이
#train:test=4:1로 맞춤.

#문항별로
#5iterations 내부에 iteration1~5가 있고, 그 내부에 train/test가 있음.

# %%
#디렉토리에 이렇게 있어야겠다.
#normal_AD/iterations/iteration1/test/abnormal: 41개
#normal_AD/iterations/iteration1/test/normal: 41개

# %%
import os
import pandas as pd
import numpy as np
import shutil #file copy
import math

filePathArr=[]
durationArr=[]
fileNameArr=[]

# %%
base_path_addr = './temp/'
versionname = 'v5'+'/SCI_AD'

# %%
#초기화

for qnum in range(1,12):
    save_path = [#'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\abnormal\\',
                 #'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\normal\\',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/AD/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/AD/',
        
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/SCI/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/SCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/SCI/'
        
        
                ]

    for dir in save_path:
        file_list = os.listdir(dir)

        for k in range(0, len(file_list)):
                        os.remove(dir+file_list[k])

# %%
base_path = [base_path_addr+versionname+'/1/AD/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/AD/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/AD/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/AD/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test

# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/SCI_AD/10/AD/
# 208
# [172 158 116 100  20  53 181 173 171 120  97  82 107 138 193 123  56 104
#  194  23   9  33 199  32  63 186  51 145  30 183   0   8 143  76 149  69
#   79 140  26 113  80  77 109 124  93 206 197 156 188 137  31  45  67 126
#    4 155  87 182 114 195 157  98  83 190  58 103 201  37  61  91 146 154
#   73  66  88 202  62  65 141  68  15  11  46  54 185 119  49 151 125  96
#  203  42  29 159 115 161  40 152 189 164  17  41 167 168  39 121  89 110
#  102 101 132  90  14  27  92 166 198  36  75 136  25  19   3  13  74 129
#  112 169 106 105 128 176  34  78  72  38  50  21  86  35  55 187 174   7
#    6 207 142  64 205 122 160 162 163  95  59 139 135 118 175 192  18 204
#   10 196 170 179   5  48 148 191  57  12  22  70 134  16  94 117 108 200
#  111 153 130  84 144 147 177 131  43 184  28  47  24 133 180   2  44 127
#   81  99   1  85  71 165  60 150 178  52]
# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/SCI_AD/11/AD/
# 208
# [172 158 116 100  20  53 181 173 171 120  97  82 107 138 193 123  56 104
#  194  23   9  33 199  32  63 186  51 145  30 183   0   8 143  76 149  69
#   79 140  26 113  80  77 109 124  93 206 197 156 188 137  31  45  67 126
#    4 155  87 182 114 195 157  98  83 190  58 103 201  37  61  91 146 154
#   73  66  88 202  62  65 141  68  15  11  46  54 185 119  49 151 125  96
#  203  42  29 159 115 161  40 152 189 164  17  41 167 168  39 121  89 110
#  102 101 132  90  14  27  92 166 198  36  75 136  25  19   3  13  74 129
#  112 169 106 105 128 176  34  78  72  38  50  21  86  35  55 187 174   7
#    6 207 142  64 205 122 160 162 163  95  59 139 135 118 175 192  18 204
#   10 196 170 179   5  48 148 191  57  12  22  70 134  16  94 117 108 200
#  111 153 130  84 144 147 177 131  43 184  28  47  24 133 180   2  44 127
#   81  99   1  85  71 165  60 150 178  52]
# 41
# 42
# 41
# 42
# 41

# %%
base_path = [base_path_addr+versionname+'/1/SCI/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/SCI/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/SCI/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/SCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/SCI/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[4])
# Out:
# 208
# [113  81 144 145  97 112  90 185  91   1 177  51  61  66  63  98  89 129
#   73  28  87 102 194  34  20 199 139 180 183 201 191 152 101  42 131 103
#  134  71 128 205  11 202  14  86 149  46  74 118 107 168  23  93 156  99
#  181  29 186  50 174  43 104  65 155 105  60 120  12 171 187  36  55 159
#  184  35 110  62 196 117 176 195  69  33 178 122 166  88  96 125 153 163
#  160 179  83  84 130   4  10 109   6 147 127  52  49  40 175 164 162  68
#  188 182  92 173 165 136  22 161 123 133 137 108  75  67  26 154 140  21
#   18   5 167  77 172 157 148 121   2 114  30  64  31   3 192  19  47 207
#   13   9  37  58 116 204 111 190  57  41 189 106 100 143 158  85  38  16
#   79  24  27 146  80  59  76 203 169 197 198  78 135  48  54  53   8  45
#    0  70  95 126 150 193  32  82 119 132  44 142 138  17   7 151 170 124
#   15  56 206 200 141  72  94  39 115  25]
# file_path ./temp/v5/SCI_AD/1/SCI/
# 208
# [113  81 144 145  97 112  90 185  91   1 177  51  61  66  63  98  89 129
#   73  28  87 102 194  34  20 199 139 180 183 201 191 152 101  42 131 103
#  134  71 128 205  11 202  14  86 149  46  74 118 107 168  23  93 156  99
#  181  29 186  50 174  43 104  65 155 105  60 120  12 171 187  36  55 159
#  184  35 110  62 196 117 176 195  69  33 178 122 166  88  96 125 153 163
#  160 179  83  84 130   4  10 109   6 147 127  52  49  40 175 164 162  68
#  188 182  92 173 165 136  22 161 123 133 137 108  75  67  26 154 140  21
#   18   5 167  77 172 157 148 121   2 114  30  64  31   3 192  19  47 207
#   13   9  37  58 116 204 111 190  57  41 189 106 100 143 158  85  38  16
#   79  24  27 146  80  59  76 203 169 197 198  78 135  48  54  53   8  45
#    0  70  95 126 150 193  32  82 119 132  44 142 138  17   7 151 170 124
#   15  56 206 200 141  72  94  39 115  25]
# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/SCI_AD