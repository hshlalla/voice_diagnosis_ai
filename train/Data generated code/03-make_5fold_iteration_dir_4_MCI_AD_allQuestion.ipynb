# %%
#5 iterations로 나누되 이번에는
#validation 없이
#train:test=4:1로 맞춤.

#문항별로
#5iterations 내부에 iteration1~5가 있고, 그 내부에 train/test가 있음.

# %%
#디렉토리에 이렇게 있어야겠다.
#MCI_AD/iterations/iteration1/test/MCI: 41개
#MCI_AD/iterations/iteration1/test/normal: 41개

# %%
import os
import pandas as pd
import numpy as np
import shutil #file copy
import math

filePathArr=[]
durationArr=[]
fileNameArr=[]

# %%
base_path_addr = './temp/'
versionname = 'v5'+'/MCI_AD'

# %%
#초기화

for qnum in range(1,12):
    save_path = [#'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\abnormal\\',
                 #'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\normal\\',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/MCI/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/MCI/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/MCI/',
        
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/AD/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/AD/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/AD/'
        
        
                ]

    for dir in save_path:
        file_list = os.listdir(dir)

        for k in range(0, len(file_list)):
                        os.remove(dir+file_list[k])

# %%
base_path = [base_path_addr+versionname+'/1/MCI/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/MCI/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/MCI/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/MCI/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/MCI/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test

# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/MCI_AD/10/MCI/
# 208
# [ 66 142 121 163  91  75  10  38 187 155  45 184 108  74 150 130  58 103
#   80 171 167 181  51 162 164  40  63  73  44 169 172 135 207  16  95 191
#  205 182 192  69 157   3  64  93 102   5 146  30 116  83  68  34  97  86
#   42 128 173  54 201 139 151 133  55 153 118   9  52  61  25  15   6 109
#   87 140  82  85 129 175 105  47   4 111 106  88  33 202 206  32 180  35
#   48  81 125 188  29 159 193  62 126 143  92 179 113  60   7 154 110  71
#   46  13 186 178 177 185  22  14 174  18 101 114 120  11 199  98  49 165
#   31 148  57  94 134 190 141  59  26 104  67 149  23  21  17   8 198 161
#   72 200 156 147  79 100 160 170  12 117 152  65 158  19  76  56  77   2
#   24  90  84 119 127  20 138 136  53  78 123 137  28 166  96 112  89 115
#   43  39  99 176  27  41 183 145 195 124 122  36 144  50 197 131   1 132
#  196 203   0  37 204 194 168 107  70 189]
# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/MCI_AD/11/MCI/
# 208
# [ 66 142 121 163  91  75  10  38 187 155  45 184 108  74 150 130  58 103
#   80 171 167 181  51 162 164  40  63  73  44 169 172 135 207  16  95 191
#  205 182 192  69 157   3  64  93 102   5 146  30 116  83  68  34  97  86
#   42 128 173  54 201 139 151 133  55 153 118   9  52  61  25  15   6 109
#   87 140  82  85 129 175 105  47   4 111 106  88  33 202 206  32 180  35
#   48  81 125 188  29 159 193  62 126 143  92 179 113  60   7 154 110  71
#   46  13 186 178 177 185  22  14 174  18 101 114 120  11 199  98  49 165
#   31 148  57  94 134 190 141  59  26 104  67 149  23  21  17   8 198 161
#   72 200 156 147  79 100 160 170  12 117 152  65 158  19  76  56  77   2
#   24  90  84 119 127  20 138 136  53  78 123 137  28 166  96 112  89 115
#   43  39  99 176  27  41 183 145 195 124 122  36 144  50 197 131   1 132
#  196 203   0  37 204 194 168 107  70 189]
# 41
# 42
# 41
# 42
# 41

# %%
base_path = [base_path_addr+versionname+'/1/AD/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/AD/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/AD/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/AD/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/AD/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[4])
# Out:
# 208
# [154  89 136 192 133  23  87 135 146 131 162  66 193  56  85  42  21 134
#   18 142 124  93  84 140  71  45   5 121  32 207 168  33  19 149  15 185
#   39 195 163  58  25 173  10 116   6  55 159  65 182 148  69 114 181  40
#   81 179   2 151  92  14  52  67 127 183  49 120 150 170  17 111 130 145
#  132 122 166  61 152  13 119 123 184  41  11   1  57   4 197  38 156 155
#   51 180  37 194 177 161  46 138  90 167 176  98  27 118 169  95 205 198
#  190  72 187  76  22  60  35  97 139 102 108 204 147  70 126 117  83 137
#  129  78 115   3  48 189  75  96  91  50 100  34 157  30   8 164 106 188
#   86  64 103 172 128  12 202  26 110  31 165  36  28  82  74 174  47 175
#   63  53 201  54 178  99  62 105  20 101  68 160   0  44  59 196   9 113
#  143 199 112 107  80 186 104 109  43 153 206 171  73 125  88 200  94 158
#   29   7 141  77 191 203  16  24 144  79]
# file_path ./temp/v5/MCI_AD/1/AD/
# 208
# [154  89 136 192 133  23  87 135 146 131 162  66 193  56  85  42  21 134
#   18 142 124  93  84 140  71  45   5 121  32 207 168  33  19 149  15 185
#   39 195 163  58  25 173  10 116   6  55 159  65 182 148  69 114 181  40
#   81 179   2 151  92  14  52  67 127 183  49 120 150 170  17 111 130 145
#  132 122 166  61 152  13 119 123 184  41  11   1  57   4 197  38 156 155
#   51 180  37 194 177 161  46 138  90 167 176  98  27 118 169  95 205 198
#  190  72 187  76  22  60  35  97 139 102 108 204 147  70 126 117  83 137
#  129  78 115   3  48 189  75  96  91  50 100  34 157  30   8 164 106 188
#   86  64 103 172 128  12 202  26 110  31 165  36  28  82  74 174  47 175
#   63  53 201  54 178  99  62 105  20 101  68 160   0  44  59 196   9 113
#  143 199 112 107  80 186 104 109  43 153 206 171  73 125  88 200  94 158
#   29   7 141  77 191 203  16  24 144  79]
# 41
# 42
# 41
# 42
# 41
# file_path ./temp/v5/MCI_AD