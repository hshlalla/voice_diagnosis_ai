# %%
#5 iterations로 나누되 이번에는
#validation 없이
#train:test=4:1로 맞춤.

#문항별로
#5iterations 내부에 iteration1~5가 있고, 그 내부에 train/test가 있음.

# %%
#디렉토리에 이렇게 있어야겠다.
#normal_abnormal/iterations/iteration1/abnormal: 58개
#normal_abnormal/iterations/iteration1/normal: 58개

# %%
import os
import pandas as pd
import numpy as np
import shutil #file copy
import math

filePathArr=[]
durationArr=[]
fileNameArr=[]

# %%
base_path_addr = './temp/'
versionname = 'v5'+'/normal_abnormal'

# %%
#초기화

for qnum in range(1,12):
    save_path = [#'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\abnormal\\',
                 #'D:\\DATA\\voice_cut\\voice_cut2\\dataset20250127\\normal_abnormal\\'+str(qnum)+'\\iterations\\test\\normal\\',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/abnormal/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/abnormal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/abnormal/',
        
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/normal/',

                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/normal/',
                 base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/normal/'
        
        
                ]

    for dir in save_path:
        file_list = os.listdir(dir)

        for k in range(0, len(file_list)):
                        os.remove(dir+file_list[k])

# %%
base_path = [base_path_addr+versionname+'/1/abnormal/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/abnormal/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/abnormal/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/abnormal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/abnormal/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[4])
# Out:
# 258
# [216 133 104 186  41 204 254 168 201 221 253  64 130 189 238 114 219 252
#  241   0 159 154 202 137   8 187 182 161  75 197  26  40  93 157 213 211
#  247  60 164 152 160 165 103 184  25 232 176  15 255 101 226  36  54  66
#  177 193  46  51 194  96 223 156 220 153   2 142  58  27 135  97 206 148
#  192  21  16 250 112 183 121  85 162  69  87 163  43 234 239 174   5 188
#  246 200  12 141  99  30 227  62  72 172  95  89 125 212 224 166  77 185
#  243  53 248 196  86 149 256  59 107 178  65 139 236   4 132  90 207  38
#  233 119  67  45 102 203 205  79 180  50 199  63  92 237  73  42 167  70
#    1 240 218  55 145  20 229 173   3  24 126 111  71 143 181 146 217 231
#   31  98 222  34  18 210 208 225  52  13  39  32 257 251 127  49  94  57
#  140  88 147 131 113  68 209  35  19  29 179 198 249  91  48 110 175 128
#  120 122 136  14 106  44  37 214 158  81 124 190   9 134 150  23   7  22
#  244 155 228 118 129 151 117  28 170 116 100   6  17  56  61 235 123  78
# ...

# %%
base_path = [base_path_addr+versionname+'/1/normal/'] #일단 환자가 다 똑같아야하므로, 순서는 미리 뽑아둠. #환자 이름별로 정렬이 다 똑같이 되어있겠지..
#file_path = dir
file_list = os.listdir(base_path[0])

print(len(file_list))

pick1=np.random.choice(len(file_list), len(file_list), replace=False)
print(pick1)


for qnum in range(1,12):
#random 비복원추출 및 파일 복사   
    base_path = [base_path_addr+versionname+'/'+str(qnum)+'/normal/']

    dir = base_path[0]

    file_path = dir
    print("file_path",file_path)
    file_list = os.listdir(file_path)

    #print(file_list[0])
    print(len(file_list))

    #pick1=np.random.choice(len(file_list), len(file_list), replace=False)
    print(pick1)

    save_path_train = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/train/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/train/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/train/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/train/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/train/normal/']
#test폴더
    save_path_test = [base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration1/test/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration2/test/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration3/test/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration4/test/normal/',
                      base_path_addr+versionname+'/'+str(qnum)+'/iterations/iteration5/test/normal/']


    #print('... start')
    print(math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.4)-math.floor(len(file_list)*0.2))
    print(math.floor(len(file_list)*0.6)-math.floor(len(file_list)*0.4))
    print(math.floor(len(file_list)*0.8)-math.floor(len(file_list)*0.6))
    print(math.floor(len(file_list)-1)-math.floor(len(file_list)*0.8))

    for k in range(0, math.floor(len(file_list)*0.2)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[0])
        #print(pick1[k])


    #print('... start')
    for k in range(math.floor(len(file_list)*0.2),math.floor(len(file_list)*0.4)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[1])
        #print(pick1[k])


    for k in range(math.floor(len(file_list)*0.4),math.floor(len(file_list)*0.6)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[2])


    for k in range(math.floor(len(file_list)*0.6),math.floor(len(file_list)*0.8)):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[4])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[3])


    for k in range(math.floor(len(file_list)*0.8),math.floor(len(file_list))-1):
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[0])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[1])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[2])
        shutil.copy(file_path+file_list[pick1[k]], save_path_train[3])
        shutil.copy(file_path+file_list[pick1[k]], save_path_test[4])
# Out:
# 258
# [238 151 148 200  76  35 147  22 248  47 226  61  10 170  15 234 150  16
#  105 146  28 123  48 141 183 116 193  38  13  54  93 104 243 251 168 169
#  125 235 129 130 144  41 220  79   0 223 213  98 134  52 163 233 110  50
#  231  42 102 101  74   7  69 181  46 180 176  83 117 186 119  43  57  33
#  256 159 227  53 242 198 140 115 208 164  78   9 255 197  12  86 241  20
#   39 153 128 202 160  85 107  91  75   8 254 156  63 165  66 210  96 109
#   25  37  94 111 250  45  19 196 230 249   5 124 114 138 108  29  77  18
#   89 143 139 162 239 188 228 154 126  21 219 252 201 167 112   3 161 257
#  207 215  73  58 178  90 132 199 191 214 121  55 157 166 221 253 218 118
#   59 145 195   2 100  24  40 245 237  44  56 179 182 103 232  14  87  49
#  106 120 190 171  80  97 236  64  60  27 247 184 174 155 205  84  51 224
#  152 244 246 203 173  30 158 212   6  65 122  92 187 133 113  72  99 172
#   71 240 216  82  67 136 175  11 149 209 217  62 229  88  95   4 135 222
# ...
